# %%
import os, sys
print("Current folder where Jupyter is running:")
print(os.getcwd())
print("\nFiles in this folder:")
print(os.listdir(os.getcwd()))

parent = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"\nParent folder: {parent}")
print(f"Files in parent: {os.listdir(parent)}")

project_path = r"C:\Users\Asus\terraspectra-infotact"
print(f"\nChecking project path: {project_path}")
print(os.listdir(project_path))
print("\nChecking backend folder:")
print(os.listdir(os.path.join(project_path, "backend")))
# Out:
# Current folder where Jupyter is running:
# C:\Users\Asus\Desktop\terraspectra-infotact\notebooks
#
# Files in this folder:
# ['.ipynb_checkpoints', '01_mock_data_generation.ipynb']
#
# Parent folder: C:\Users\Asus\Desktop\terraspectra-infotact
# Files in parent: ['.git', 'backend', 'data', 'notebooks', 'README.md']
#
# Checking project path: C:\Users\Asus\terraspectra-infotact
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 13
#      11 project_path = r"C:\Users\Asus\terraspectra-infotact"
#      12 print(f"\nChecking project path: {project_path}")
# ---> 13 print(os.listdir(project_path))
#      14 print("\nChecking backend folder:")
#      15 print(os.listdir(os.path.join(project_path, "backend")))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Asus\\terraspectra-infotact'

# %%
import sys
sys.path.append(r"C:\Users\Asus\Desktop\terraspectra-infotact")
from backend.backend_dat import HyperspectralDataset
print("SUCCESS! Working!")
# Out:
# SUCCESS! Working!

# %%
import numpy as np
import torch

# Create fake hyperspectral data
print("Generating mock data...")
mock_cube = np.random.rand(100, 10, 10, 50) # 100 samples, 10x10, 50 bands

dataset = HyperspectralDataset(mock_cube)

print(f"Total samples: {len(dataset)}")
print(f"One sample shape: {dataset[0].shape}")
print("Mock data ready for TerraSpectra!")
# Out:
# Generating mock data...
# Total samples: 100
# One sample shape: torch.Size([10, 10, 50])
# Mock data ready for TerraSpectra!
